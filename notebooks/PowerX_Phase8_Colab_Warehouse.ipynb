# %% [markdown]
# # PowerX Phase 8 — Drive Warehouse\n

# %%
from google.colab import drive\ndrive.mount('/content/drive')\n

# %%
# !pip -q install huggingface_hub fastapi uvicorn httpx pydantic\n

# %%
# !python scripts_phase8/warehouse_init.py\n# !python runtime_nodes/colab/seed_warehouse.py\n
